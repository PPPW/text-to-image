# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.vision.gan import *

# %% [markdown]
# Fastai version in this notebook:

# %%
__version__
# Out:
# '1.0.48.dev0'

# %%
git log -3
# Out:
# commit 4022362f0132640375afd15b7dcb7d932d9740d0
# Author: PPPW <pei.wang.fudan@gmail.com>
# Date:   Fri Mar 8 19:43:35 2019 -0500
#
#     Fix gan to adapt callback API changes
#
# commit a8ff26a925511902353136751a05f3b68fa3fcd9
# Author: Konstantin Dorichev <kdorichev@gmail.com>
# Date:   Sat Mar 9 02:19:47 2019 +0300
#
#     Added earlier committed tests to this_tests. (#1790)
#
# commit 5f4963869dfd01d184468f8871218344b3b0bad1
# Author: Aaron Swaving <aaron.swaving@gmail.com>
# Date:   Sat Mar 9 00:19:25 2019 +0100
#
#     updated wide resnet docs (#1792)

# %% [markdown]
# ## data

# %%
embedding = torch.load('embedding.pkl')

# %%
class Txt2ImgYItemList(ItemList):
    def __init__(self, items, embedding=embedding, **kwargs):
        super().__init__(items, **kwargs)        
        self.embedding = embedding 
        self.copy_new.append('embedding')

    def get(self, i): 
        fn = self.items[i]
        key = fn.name.split('.')[0] + '.txt'
        # return: embedding, image
        return self.embedding[key].cuda(), open_image(fn, convert_mode='RGB')      
    
    def reconstruct(self, t):
        return Image(t.float().clamp(min=0,max=1))
        
    def show_xys(self, xs, ys, imgsize=4, figsize=None, **kwargs):
        raise NotImplementedError

    def show_xyzs(self, xs, ys, zs, imgsize=4, figsize=None, **kwargs):
        raise NotImplementedError

# %%
class Txt2ImgXItemList(ItemList):    
    _label_cls = Txt2ImgYItemList

    def __init__(self, items, embedding=embedding, **kwargs):
        super().__init__(items, **kwargs)        
        self.embedding = embedding 
        self.copy_new.append('embedding')
        
    def get(self, i): 
        fn = self.items[i]
        key = fn.name.split('.')[0] + '.txt'        
        # return: embedding, wrong image
        return self.embedding[key].cuda()#, self.get_wrong_image(i)
    
    def get_wrong_image(self, i):        
        cat = '_'.join(self.items[i].name.split('_')[:-3])
        idx = np.random.randint(len(self))

        if not self.items[idx].name.startswith(cat):
            return open_image(self.items[idx], convert_mode='RGB')

        return self.get_wrong_image(i)
            
    def reconstruct(self, t):
        raise NotImplementedError            
    
    def show_xys(self, xs, ys, imgsize=4, figsize=None, **kwargs):
        raise NotImplementedError

    def show_xyzs(self, xs, ys, zs, imgsize=4, figsize=None, **kwargs):
        raise NotImplementedError

# %%
data = (Txt2ImgXItemList
            .from_folder('data/images/')
            #.from_folder('sample/images/train')
            #.use_partial_data()
            #.split_by_rand_pct(valid_pct=0.1)
            .split_none()            
            .label_from_func(noop)
            .databunch(bs=128, num_workers=0)) # num_workers: for Windows
            # TODO: normalize?

# %%
data.train_dl.dl.pin_memory = False  # why?

# %%
item = next(iter(data.train_dl))

# %%
item[0][0].shape, item[0][1].shape, item[1][0].shape, item[1][1].shape
# Out:
# (torch.Size([400, 1, 1]),
#  torch.Size([400, 1, 1]),
#  torch.Size([128, 400, 1, 1]),
#  torch.Size([128, 3, 64, 64]))

# %% [markdown]
# ## model

# %%
def avg_flatten(x): return x.mean(0).view(1)

def AvgFlatten(): return Lambda(avg_flatten)  # now can pickle

# %%
def squeezer(in_dim, out_dim):
    return nn.Sequential(
            nn.Linear(in_dim, out_dim),
            nn.BatchNorm1d(out_dim),
            nn.LeakyReLU(0.2, inplace=True)
        )

# %%
class Txt2ImgGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.generator = basic_generator(in_size=64, n_channels=3, noise_sz=228)
        self.squeezer = squeezer(400, 128)
    
    def forward(self, embedding, fake_image=None):        
        em_s = self.squeezer(embedding.view(embedding.size(0), -1))
        em_s = em_s[:,:,None,None]
        em_noise = torch.cat([em_s, torch.randn(em_s.size(0),100,1,1).cuda()], 1)
        # return: (embedding, fake image)
        return embedding, self.generator(em_noise)

# %%
class Txt2ImgCritic(nn.Module):
    def __init__(self):
        super().__init__()
        critic = basic_critic(in_size=64, n_channels=3)
        self.body = nn.Sequential(*list(critic.children())[:-2])
        self.head = nn.Sequential(conv2d(640, 1, 4, padding=0), 
                                  AvgFlatten())
        self.squeezer = squeezer(400, 128)
        
    def forward(self, embedding, image):
        x = self.body(image)                     # (512,4,4)
        em_s = self.squeezer(embedding.view(embedding.size(0), -1)) 
        em_s = em_s[:,:,None,None]               # (128,1,1)
        em_s = em_s.repeat(1,1,4,4)              # (128,4,4)
        x = torch.cat([x, em_s], 1)              # (640,4,4)
        x = self.head(x)
        return x

# %%
class Txt2ImgLoss(GANModule):    
    def __init__(self, gan_model):
        super().__init__()
        self.gan_model = gan_model

    def generator(self, output, *target):
        # output: (embedding, image)
        # target: (embedding, image)
        fake_pred = self.gan_model.critic(*output)        
        return fake_pred.mean()

    def critic(self, real_pred, embedding, wrong_img=None):
        # real_pred: (1,)
        fake = self.gan_model.generator(embedding.requires_grad_(False))
        # fake: (embedding, fake image)
        fake[1].requires_grad_(True)
        fake_pred = self.gan_model.critic(*fake)  
        #wrong_pred = self.gan_model.critic(fake[0], wrong_img)
        return real_pred.mean() - fake_pred.mean() #- wrong_pred.mean()

# %%
class Txt2ImgGANTrainer(GANTrainer):    
    def on_backward_begin(self, last_loss, last_output, **kwargs):        
        last_loss = last_loss.detach().cpu()
        if self.gen_mode:
            self.smoothenerG.add_value(last_loss)
            self.glosses.append(self.smoothenerG.smooth)
            # last_output: (embedding, image)
            self.last_gen = last_output[1].detach().cpu()
        else:
            self.smoothenerC.add_value(last_loss)
            self.closses.append(self.smoothenerC.smooth)

# %%
generator = Txt2ImgGenerator()
critic = Txt2ImgCritic()

# %%
gan = GANModule(generator, critic)
loss_func = Txt2ImgLoss(gan)
switcher = partial(FixedGANSwitcher, n_crit=5, n_gen=1)

# %%
learn = Learner(data, gan, loss_func=loss_func, 
                opt_func = partial(optim.Adam, betas = (0.,0.99)), wd=0.,
                callback_fns=[switcher], path='.')

# %%
trainer = Txt2ImgGANTrainer(learn, clip=0.01, switch_eval=False, show_img=True)
learn.gan_trainer = trainer
learn.callbacks.append(trainer)

# %% [markdown]
# ## train

# %%
_ = learn.load('m5', purge=False)  # purge not working?

# %%
learn.opt_func = partial(optim.Adam, betas = (0.5,0.99))

# %%
learn.opt_func, learn.callback_fns
# Out:
# (functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.5, 0.99)),
#  [functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True),
#   functools.partial(<class 'fastai.vision.gan.FixedGANSwitcher'>, n_crit=5, n_gen=1)])

# %%
learn.fit(80, 2e-4)
# Out:
# Total time: 3:12:15 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>gen_loss</th>
#     <th>disc_loss</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>-0.227448</th>
#     <th>0.135231</th>
#     <th>-0.301094</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>-0.220560</th>
#     <th>0.145949</th>
#     <th>-0.298487</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>-0.226004</th>
#     <th>0.146855</th>
#     <th>-0.299310</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>-0.221887</th>
#     <th>0.152017</th>
#     <th>-0.298482</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>-0.230831</th>
#     <th>0.143735</th>
#     <th>-0.299186</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>-0.229151</th>
#     <th>0.136372</th>
#     <th>-0.303933</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>-0.223140</th>
#     <th>0.147523</th>
#     <th>-0.296644</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>-0.228195</th>
#     <th>0.143516</th>
#     <th>-0.302517</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>-0.229421</th>
#     <th>0.139109</th>
#     <th>-0.298510</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>-0.230456</th>
#     <th>0.146185</th>
#     <th>-0.302344</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>-0.230895</th>
#     <th>0.144175</th>
#     <th>-0.301654</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>-0.225725</th>
#     <th>0.143557</th>
#     <th>-0.302880</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>-0.223424</th>
#     <th>0.141878</th>
#     <th>-0.300779</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>-0.230524</th>
#     <th>0.138919</th>
#     <th>-0.304568</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>-0.225366</th>
#     <th>0.143807</th>
#     <th>-0.297496</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>-0.226452</th>
#     <th>0.142843</th>
#     <th>-0.301840</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>-0.229717</th>
#     <th>0.146412</th>
#     <th>-0.300831</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>-0.216578</th>
#     <th>0.152995</th>
#     <th>-0.299217</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>-0.223148</th>
#     <th>0.145941</th>
#     <th>-0.300174</th>
#     <th>02:29</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>-0.223034</th>
#     <th>0.147487</th>
#     <th>-0.298951</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>-0.230669</th>
#     <th>0.145804</th>
#     <th>-0.305639</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>-0.231632</th>
#     <th>0.134563</th>
#     <th>-0.298021</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>-0.228422</th>
#     <th>0.146276</th>
#     <th>-0.301387</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>-0.220481</th>
#     <th>0.152878</th>
#     <th>-0.300428</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>-0.228159</th>
#     <th>0.145083</th>
#     <th>-0.302592</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>-0.222626</th>
#     <th>0.147560</th>
#     <th>-0.299843</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>-0.224499</th>
#     <th>0.149109</th>
#     <th>-0.298885</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>-0.232273</th>
#     <th>0.143495</th>
#     <th>-0.301848</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>-0.227961</th>
#     <th>0.146285</th>
#     <th>-0.298439</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>-0.225170</th>
#     <th>0.143609</th>
#     <th>-0.300806</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>-0.228602</th>
#     <th>0.145161</th>
#     <th>-0.303235</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>-0.226111</th>
#     <th>0.142045</th>
#     <th>-0.297659</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>-0.228719</th>
#     <th>0.139400</th>
#     <th>-0.302343</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>-0.228532</th>
#     <th>0.144131</th>
#     <th>-0.300305</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>-0.232496</th>
#     <th>0.145411</th>
#     <th>-0.303782</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>-0.223899</th>
#     <th>0.145148</th>
#     <th>-0.301586</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>-0.226399</th>
#     <th>0.140469</th>
#     <th>-0.301522</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>-0.228983</th>
#     <th>0.145108</th>
#     <th>-0.306795</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>-0.225481</th>
#     <th>0.144835</th>
#     <th>-0.297312</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>-0.224377</th>
#     <th>0.152178</th>
#     <th>-0.298675</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>-0.226193</th>
#     <th>0.149988</th>
#     <th>-0.298203</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>-0.225804</th>
#     <th>0.137443</th>
#     <th>-0.301514</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>-0.228142</th>
#     <th>0.144072</th>
#     <th>-0.304174</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>-0.225415</th>
#     <th>0.141471</th>
#     <th>-0.296570</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>-0.227003</th>
#     <th>0.147468</th>
#     <th>-0.300989</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>-0.228178</th>
#     <th>0.143529</th>
#     <th>-0.298241</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>-0.231548</th>
#     <th>0.144017</th>
#     <th>-0.302454</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>-0.223834</th>
#     <th>0.143179</th>
#     <th>-0.302792</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>-0.225676</th>
#     <th>0.146105</th>
#     <th>-0.301285</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>-0.229143</th>
#     <th>0.146851</th>
#     <th>-0.305224</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>-0.229042</th>
#     <th>0.145547</th>
#     <th>-0.300677</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>51</th>
#     <th>-0.227685</th>
#     <th>0.148672</th>
#     <th>-0.300947</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>52</th>
#     <th>-0.232696</th>
#     <th>0.143935</th>
#     <th>-0.303989</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>53</th>
#     <th>-0.224990</th>
#     <th>0.142287</th>
#     <th>-0.303349</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>54</th>
#     <th>-0.222378</th>
#     <th>0.147415</th>
#     <th>-0.299925</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>55</th>
#     <th>-0.226926</th>
#     <th>0.143509</th>
#     <th>-0.300930</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>56</th>
#     <th>-0.222020</th>
#     <th>0.150936</th>
#     <th>-0.299476</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>57</th>
#     <th>-0.229264</th>
#     <th>0.139203</th>
#     <th>-0.300277</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>58</th>
#     <th>-0.226194</th>
#     <th>0.144988</th>
#     <th>-0.297561</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>59</th>
#     <th>-0.220771</th>
#     <th>0.148552</th>
#     <th>-0.300147</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>60</th>
#     <th>-0.219214</th>
#     <th>0.149556</th>
#     <th>-0.297143</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>61</th>
#     <th>-0.227445</th>
#     <th>0.144223</th>
#     <th>-0.301872</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>62</th>
#     <th>-0.228851</th>
#     <th>0.148313</th>
#     <th>-0.305312</th>
#     <th>02:26</th>
#   </tr>
#   <tr>
#     <th>63</th>
#     <th>-0.229596</th>
#     <th>0.139117</th>
#     <th>-0.298487</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>64</th>
#     <th>-0.232723</th>
#     <th>0.141784</th>
#     <th>-0.301459</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>65</th>
#     <th>-0.220711</th>
#     <th>0.144618</th>
#     <th>-0.299623</th>
#     <th>02:25</th>
#   </tr>
#   <tr>

# %%
learn.save('m5')

# %%
learn.fit(80, 2e-4)
# Out:
# Total time: 3:12:39 <p><table style='width:450px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>gen_loss</th>
#     <th>disc_loss</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>-0.221093</th>
#     <th>0.141094</th>
#     <th>-0.297870</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>-0.228427</th>
#     <th>0.134964</th>
#     <th>-0.299693</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>-0.229705</th>
#     <th>0.142580</th>
#     <th>-0.301874</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>-0.229222</th>
#     <th>0.148383</th>
#     <th>-0.301642</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>-0.229633</th>
#     <th>0.144974</th>
#     <th>-0.300935</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>-0.221717</th>
#     <th>0.141349</th>
#     <th>-0.299392</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>-0.224727</th>
#     <th>0.149744</th>
#     <th>-0.301147</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>-0.224719</th>
#     <th>0.150165</th>
#     <th>-0.299380</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>-0.228086</th>
#     <th>0.148966</th>
#     <th>-0.300422</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>-0.227858</th>
#     <th>0.144503</th>
#     <th>-0.300213</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>-0.231263</th>
#     <th>0.144613</th>
#     <th>-0.300427</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>-0.221645</th>
#     <th>0.140028</th>
#     <th>-0.299654</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>-0.229255</th>
#     <th>0.144319</th>
#     <th>-0.305019</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>-0.225158</th>
#     <th>0.144660</th>
#     <th>-0.300748</th>
#     <th>02:28</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>-0.226684</th>
#     <th>0.147129</th>
#     <th>-0.300875</th>
#     <th>02:20</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>-0.232098</th>
#     <th>0.142791</th>
#     <th>-0.301750</th>
#     <th>02:20</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>-0.229409</th>
#     <th>0.144623</th>
#     <th>-0.301699</th>
#     <th>02:20</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>-0.224093</th>
#     <th>0.145839</th>
#     <th>-0.301241</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>-0.227134</th>
#     <th>0.146082</th>
#     <th>-0.302350</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>-0.229737</th>
#     <th>0.143109</th>
#     <th>-0.303910</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>-0.225287</th>
#     <th>0.144555</th>
#     <th>-0.297768</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>-0.229315</th>
#     <th>0.144191</th>
#     <th>-0.301380</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>-0.233546</th>
#     <th>0.140340</th>
#     <th>-0.301757</th>
#     <th>02:21</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>-0.220478</th>
#     <th>0.149179</th>
#     <th>-0.299762</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>-0.223150</th>
#     <th>0.156217</th>
#     <th>-0.303904</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>-0.229713</th>
#     <th>0.147256</th>
#     <th>-0.304674</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>-0.227505</th>
#     <th>0.145470</th>
#     <th>-0.301261</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>-0.224080</th>
#     <th>0.147598</th>
#     <th>-0.298636</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>-0.230020</th>
#     <th>0.150986</th>
#     <th>-0.303262</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>-0.221884</th>
#     <th>0.146705</th>
#     <th>-0.300699</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>-0.226328</th>
#     <th>0.148324</th>
#     <th>-0.302427</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>-0.228129</th>
#     <th>0.142847</th>
#     <th>-0.302067</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>-0.221835</th>
#     <th>0.151390</th>
#     <th>-0.296913</th>
#     <th>02:22</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>-0.229937</th>
#     <th>0.147810</th>
#     <th>-0.302156</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>-0.226929</th>
#     <th>0.146650</th>
#     <th>-0.298605</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>-0.224114</th>
#     <th>0.149411</th>
#     <th>-0.301569</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>-0.224589</th>
#     <th>0.141071</th>
#     <th>-0.298446</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>-0.227312</th>
#     <th>0.146841</th>
#     <th>-0.303133</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>-0.229727</th>
#     <th>0.140737</th>
#     <th>-0.299483</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>-0.224749</th>
#     <th>0.152974</th>
#     <th>-0.299083</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>-0.227384</th>
#     <th>0.149202</th>
#     <th>-0.298193</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>-0.219875</th>
#     <th>0.157004</th>
#     <th>-0.300991</th>
#     <th>02:23</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>-0.223328</th>
#     <th>0.147582</th>
#     <th>-0.299882</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>-0.223056</th>
#     <th>0.145923</th>
#     <th>-0.298891</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>-0.229602</th>
#     <th>0.151112</th>
#     <th>-0.303590</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>-0.227780</th>
#     <th>0.153627</th>
#     <th>-0.301584</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>-0.232322</th>
#     <th>0.150683</th>
#     <th>-0.302884</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>-0.226225</th>
#     <th>0.137891</th>
#     <th>-0.300921</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>-0.221131</th>
#     <th>0.146969</th>
#     <th>-0.301395</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>-0.226762</th>
#     <th>0.145184</th>
#     <th>-0.299541</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>-0.225851</th>
#     <th>0.150337</th>
#     <th>-0.301399</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>51</th>
#     <th>-0.225937</th>
#     <th>0.149010</th>
#     <th>-0.302487</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>52</th>
#     <th>-0.231110</th>
#     <th>0.148243</th>
#     <th>-0.304122</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>53</th>
#     <th>-0.225249</th>
#     <th>0.149468</th>
#     <th>-0.306497</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>54</th>
#     <th>-0.227266</th>
#     <th>0.138654</th>
#     <th>-0.300277</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>55</th>
#     <th>-0.227674</th>
#     <th>0.148015</th>
#     <th>-0.302293</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>56</th>
#     <th>-0.234842</th>
#     <th>0.145290</th>
#     <th>-0.306797</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>57</th>
#     <th>-0.227580</th>
#     <th>0.147980</th>
#     <th>-0.301947</th>
#     <th>02:24</th>
#   </tr>
#   <tr>
#     <th>58</th>
#     <th>-0.229342</th>
#     <th>0.145272</th>
#     <th>-0.300988</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>59</th>
#     <th>-0.221714</th>
#     <th>0.142843</th>
#     <th>-0.297925</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>60</th>
#     <th>-0.225632</th>
#     <th>0.142190</th>
#     <th>-0.301778</th>
#     <th>02:27</th>
#   </tr>
#   <tr>
#     <th>61</th>
#     <th>-0.224957</th>
#     <th>0.147533</th>
#     <th>-0.303458</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>62</th>
#     <th>-0.227169</th>
#     <th>0.148255</th>
#     <th>-0.301983</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>63</th>
#     <th>-0.226259</th>
#     <th>0.148877</th>
#     <th>-0.301782</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>64</th>
#     <th>-0.230166</th>
#     <th>0.144450</th>
#     <th>-0.301398</th>
#     <th>02:25</th>
#   </tr>
#   <tr>
#     <th>65</th>
#     <th>-0.223359</th>
#     <th>0.145264</th>
#     <th>-0.302738</th>
#     <th>02:25</th>
#   </tr>
#   <tr>

# %%
learn.save('m5')

# %%
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Test

# %%
torch.save(learn.model.generator.state_dict(), 'models/gan_gen.pkl')

# %%
model = Txt2ImgGenerator()
model.load_state_dict(torch.load('models/gan_gen.pkl'))
_ = model.to('cuda')
_ = model.eval()

# %%
em = embedding['Summer_Tanager_0001_139289_0.txt'].cuda()

# %%
next(model.parameters()).device, em.device
# Out:
# (device(type='cuda', index=0), device(type='cuda', index=0))

# %%
with torch.no_grad():
    _, img = model(em[None])
    Image(img[0].cpu().float().clamp(min=0,max=1)).resize(100).show()

# %%
em = embedding['Sayornis_0002_98596_0.txt'].cuda()
f, ax = plt.subplots(3, 3, figsize=(5,5))
with torch.no_grad():
    for i in range(9):
        _, img = model(em[None])
        gen = Image(img[0].cpu().float().clamp(min=0,max=1))
        gen.save(f'tmp/test_{i}.jpg')
        gen.show(ax.ravel()[i])

# %%
with open('tmp/sample.txt') as f:
    for line in f:
        des = line.strip()
        em = embedding[f'{des}.txt'].cuda()
        with torch.no_grad():
            for i in range(9):
                _, img = model(em[None])
                Image(img[0].cpu().float().clamp(min=0,max=1)).save(f'tmp/gen/{des}_{i}.jpg')
